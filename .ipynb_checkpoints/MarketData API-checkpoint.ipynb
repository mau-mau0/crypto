# %%
import requests
from requests import Session
import pandas as pd

# %%
class MarketData:
    
    def __init__(self):
        self.apiurl = 'https://api.kucoin.com'
        self.session = Session()
        
    def getAllTickers(self):
        url = self.apiurl + '/api/v1/market/allTickers'
        r = self.session.get(url)
        data = r.json()['data']
        return data
    
    def getTicker(self, symbol):
        url = self.apiurl + '/api/v1/market/orderbook/level1'
        parameters = {'symbol': symbol}
        r = self.session.get(url, params=parameters)
        data = r.json()['data']
        return data
    
    def getFullOrderBook(self, symbol): # needs headers and API key
        url = self.apiurl + '/api/v3/market/orderbook/level2'
        parameters = {'symbol': symbol}
        r = self.session.get(url, params=parameters)
        data = r.json()
        return data

# %%
kucoinAPI = MarketData()

# %%
kucoinAPI.getAllTickers()
# Out:
# {'time': 1653200228056,
#  'ticker': [{'symbol': 'NKN-USDT',
#    'symbolName': 'NKN-USDT',
#    'buy': '0.0985',
#    'sell': '0.0989',
#    'changeRate': '0.0228',
#    'changePrice': '0.0022',
#    'high': '0.1028',
#    'low': '0.0954',
#    'vol': '250619.32979423',
#    'volValue': '24572.096587775937',
#    'last': '0.0986',
#    'averagePrice': '0.09267803',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'LOOM-BTC',
#    'symbolName': 'LOOM-BTC',
#    'buy': '0.00000173',
#    'sell': '0.00000175',
#    'changeRate': '0.0479',
#    'changePrice': '0.00000008',
#    'high': '0.00000181',
#    'low': '0.00000166',
#    'vol': '171325.14990286',
#    'volValue': '0.295146378502986',
#    'last': '0.00000175',
#    'averagePrice': '0.00000167',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'JUP-ETH',
#    'symbolName': 'JUP-ETH',
#    'buy': '0.00000275',
#    'sell': '0.00000277',
#    'changeRate': '-0.0107',
#    'changePrice': '-0.00000003',
#    'high': '0.00000295',
#    'low': '0.00000273',
#    'vol': '21403743.1464',
#    'volValue': '60.402027663863',
#    'last': '0.00000276',
#    'averagePrice': '0.00000325',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'CUSD-USDT',
#    'symbolName': 'CUSD-USDT',
#    'buy': '0.9978',
#    'sell': '0.9979',
#    'changeRate': '0.001',
#    'changePrice': '0.001',
#    'high': '0.998',
#    'low': '0.9956',
#    'vol': '139846.8862',
#    'volValue': '139411.7967558',
#    'last': '0.9978',
#    'averagePrice': '0.99764476',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'LTC3L-USDT',
#    'symbolName': 'LTC3L-USDT',
#    'buy': '0.010626',
#    'sell': '0.010676',
#    'changeRate': '0.03',
#    'changePrice': '0.000309',
#    'high': '0.011009',
#    'low': '0.010059',
#    'vol': '1461069.48265061',
#    'volValue': '15373.73935055798471',
#    'last': '0.010581',
#    'averagePrice': '0.01103939',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'NEO-BTC',
#    'symbolName': 'NEO-BTC',
#    'buy': '0.0003545',
#    'sell': '0.0003547',
#    'changeRate': '0.026',
#    'changePrice': '0.000009',
#    'high': '0.0003579',
#    'low': '0.0003445',
#    'vol': '894.14581479',
#    'volValue': '0.314510505271852',
#    'last': '0.0003547',
#    'averagePrice': '0.00034998',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'KNC-USDT',
#    'symbolName': 'KNC-USDT',
#    'buy': '2.556',
#    'sell': '2.561',
#    'changeRate': '0.0039',
#    'changePrice': '0.01',
#    'high': '2.671',
#    'low': '2.459',
#    'vol': '276527.09797439',
#    'volValue': '702649.66862868178',
#    'last': '2.558',
#    'averagePrice': '2.16783372',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'LYM-USDT',
#    'symbolName': 'LYM-USDT',
#    'buy': '0.002791',
#    'sell': '0.002802',
#    'changeRate': '0.0003',
#    'changePrice': '0.000001',
#    'high': '0.003129',
#    'low': '0.002692',
#    'vol': '43276715.38498424',
#    'volValue': '121264.53144737065272',
#    'last': '0.0028',
#    'averagePrice': '0.00263445',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'GRIN-BTC',
#    'symbolName': 'GRIN-BTC',
#    'buy': '0.0000048',
#    'sell': '0.00000487',
#    'changeRate': '-0.0204',
#    'changePrice': '-0.0000001',
#    'high': '0.00000604',
#    'low': '0.00000476',
#    'vol': '100314.3816707',
#    'volValue': '0.5304211203617605',
#    'last': '0.0000048',
#    'averagePrice': '0.00000663',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'NIM-ETH',
#    'symbolName': 'NIM-ETH',
#    'buy': '0.00000077',
#    'sell': '0.00000078',
#    'changeRate': '-0.0126',
#    'changePrice': '-0.00000001',
#    'high': '0.00000079',
#    'low': '0.00000077',
#    'vol': '1541516.078',
#    'volValue': '1.20041364719',
#    'last': '0.00000078',
#    'averagePrice': '0.00000078',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'SUTER-BTC',
#    'symbolName': 'SUTER-BTC',
#    'buy': '0.00000003',
#    'sell': '0.00000004',
#    'changeRate': '0',
#    'changePrice': '0',
#    'high': '0.00000004',
#    'low': '0.00000003',
#    'vol': '1496958.113375',
#    'volValue': '0.059845854257',
#    'last': '0.00000004',
#    'averagePrice': '0.00000003',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'NULS-BTC',
#    'symbolName': 'NULS-BTC',
#    'buy': '0.00000724',
#    'sell': '0.0000073',
#    'changeRate': '0.0097',
#    'changePrice': '0.00000007',
#    'high': '0.0000075',
#    'low': '0.0000071',
#    'vol': '3098.777411',
#    'volValue': '0.02257537998475',
#    'last': '0.00000723',
#    'averagePrice': '0.00000727',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'HAI-USDT',
#    'symbolName': 'HAI-USDT',
#    'buy': '0.02277',
#    'sell': '0.02287',
#    'changeRate': '-0.0737',
#    'changePrice': '-0.00182',
#    'high': '0.02479',
#    'low': '0.02053',
#    'vol': '11195027.49887558',
#    'volValue': '256405.9947547089646',
#    'last': '0.02285',
#    'averagePrice': '0.02362992',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'MITX-USDT',
#    'symbolName': 'MITX-USDT',
#    'buy': '0.01159',
#    'sell': '0.01165',
#    'changeRate': '0.0769',
#    'changePrice': '0.00083',
#    'high': '0.01249',
#    'low': '0.0104',
#    'vol': '4612177.78824818',
#    'volValue': '51580.8007007907251',
#    'last': '0.01161',
#    'averagePrice': '0.01156158',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'PDEX-USDT',
#    'symbolName': 'PDEX-USDT',
#    'buy': '1.8054',
#    'sell': '1.8144',
#    'changeRate': '0.111',
#    'changePrice': '0.1804',
#    'high': '1.8964',
#    'low': '1.6193',
#    'vol': '115387.44728961',
#    'volValue': '201739.912514355499',
#    'last': '1.8054',
#    'averagePrice': '1.97461347',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '3',
#    'makerCoefficient': '3'},
#   {'symbol': 'HTR-BTC',
#    'symbolName': 'HTR-BTC',
#    'buy': '0.00000632',
#    'sell': '0.00000636',
#    'changeRate': '0.0443',
#    'changePrice': '0.00000027',
#    'high': '0.0000066',
#    'low': '0.00000607',
#    'vol': '106262.43967749',
#    'volValue': '0.6728453053286391',
#    'last': '0.00000636',
#    'averagePrice': '0.00000644',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'FLAME-USDT',
#    'symbolName': 'FLAME-USDT',
#    'buy': '0.0738',
#    'sell': '0.0744',
#    'changeRate': '0.0787',
#    'changePrice': '0.0054',
#    'high': '0.0768',
#    'low': '0.0666',
#    'vol': '8532217.70270259',
#    'volValue': '590844.918965282441',
#    'last': '0.074',
#    'averagePrice': '0.07374614',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'EPX-USDT',
#    'symbolName': 'EPX-USDT',
#    'buy': '0.001719',
#    'sell': '0.00172',
#    'changeRate': '0.159',
#    'changePrice': '0.000236',
#    'high': '0.001788',
#    'low': '0.00144',
#    'vol': '86288239.16625621',
#    'volValue': '138885.44564883025004',
#    'last': '0.00172',
#    'averagePrice': '0.00140045',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'PUNDIX-BTC',
#    'symbolName': 'PUNDIX-BTC',
#    'buy': '0.0000169',
#    'sell': '0.00001712',
#    'changeRate': '0.0464',
#    'changePrice': '0.00000076',
#    'high': '0.00001712',
#    'low': '0.00001624',
#    'vol': '636.8118',
#    'volValue': '0.010679053313',
#    'last': '0.00001712',
#    'averagePrice': '0.00001618',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'VET-BTC',
#    'symbolName': 'VET-BTC',
#    'buy': '0.000001055',
#    'sell': '0.000001057',
#    'changeRate': '0.0272',
#    'changePrice': '0.000000028',
#    'high': '0.000001056',
#    'low': '0.000001026',
#    'vol': '2232620.90910877',
#    'volValue': '2.32991181000646547',
#    'last': '0.000001056',
#    'averagePrice': '0.00000104',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'ATOM3L-USDT',
#    'symbolName': 'ATOM3L-USDT',
#    'buy': '0.004113',
#    'sell': '0.004139',
#    'changeRate': '-0.0045',
#    'changePrice': '-0.000019',
#    'high': '0.004669',
#    'low': '0.003796',
#    'vol': '77359107.87795756',
#    'volValue': '320471.72257192942521',
#    'last': '0.004123',
#    'averagePrice': '0.00427158',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'ATOM-UST',
#    'symbolName': 'ATOM-UST',
#    'buy': '156.1846',
#    'sell': '157.6066',
#    'changeRate': '-0.1839',
#    'changePrice': '-35.2042',
#    'high': '235.4661',
#    'low': '148.6478',
#    'vol': '5340.61895607',
#    'volValue': '1034616.744493211115',
#    'last': '156.1846',
#    'averagePrice': '119.85916676',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'TWT-BTC',
#    'symbolName': 'TWT-BTC',
#    'buy': '0.00002211',
#    'sell': '0.00002213',
#    'changeRate': '0.0095',
#    'changePrice': '0.00000021',
#    'high': '0.00002261',
#    'low': '0.00002185',
#    'vol': '10565.0909',
#    'volValue': '0.235250180628',
#    'last': '0.00002211',
#    'averagePrice': '0.00002227',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'AGLD-USDT',
#    'symbolName': 'AGLD-USDT',
#    'buy': '0.6454',
#    'sell': '0.6493',
#    'changeRate': '0.1937',
#    'changePrice': '0.1049',
#    'high': '0.7475',
#    'low': '0.5316',
#    'vol': '747105.39017677',
#    'volValue': '484077.760637863214',
#    'last': '0.6464',
#    'averagePrice': '0.5223454',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'KAI-ETH',
#    'symbolName': 'KAI-ETH',
#    'buy': '0.00000761',
#    'sell': '0.00000762',
#    'changeRate': '-0.0342',
#    'changePrice': '-0.00000027',
#    'high': '0.00000821',
#    'low': '0.00000755',
#    'vol': '368425.0556',
#    'volValue': '2.908210856699',
#    'last': '0.00000762',
#    'averagePrice': '0.00000736',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'YLD-USDT',
#    'symbolName': 'YLD-USDT',
#    'buy': '0.1803',
#    'sell': '0.1806',
#    'changeRate': '0.0699',
#    'changePrice': '0.0118',
#    'high': '0.1918',
#    'low': '0.1654',
#    'vol': '528729.45893287',
#    'volValue': '94382.310637455506',
#    'last': '0.1806',
#    'averagePrice': '0.16334664',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'CPC-ETH',
#    'symbolName': 'CPC-ETH',
#    'buy': '0.000001705',
#    'sell': '0.000001735',
#    'changeRate': '0',
#    'changePrice': '0',
#    'high': '0.000001745',
#    'low': '0.000001681',
#    'vol': '19677657.2156',
#    'volValue': '33.8557641640989',
#    'last': '0.000001712',
#    'averagePrice': '0.0000017',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'COTI-BTC',
#    'symbolName': 'COTI-BTC',
#    'buy': '0.00000369',
#    'sell': '0.000003708',
#    'changeRate': '0.024',
#    'changePrice': '0.000000087',
#    'high': '0.000003772',
#    'low': '0.000003613',
#    'vol': '393982.10223577',
#    'volValue': '1.45823984701089208',
#    'last': '0.000003708',
#    'averagePrice': '0.00000371',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'POWR-USDT',
#    'symbolName': 'POWR-USDT',
#    'buy': '0.2621',
#    'sell': '0.2624',
#    'changeRate': '0.0619',
#    'changePrice': '0.0153',
#    'high': '0.2785',
#    'low': '0.2456',
#    'vol': '205974.71123446',
#    'volValue': '54526.848604587399',
#    'last': '0.2621',
#    'averagePrice': '0.25162244',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'CWS-USDT',
#    'symbolName': 'CWS-USDT',
#    'buy': '1.394',
#    'sell': '1.395',
#    'changeRate': '-0.0332',
#    'changePrice': '-0.048',
#    'high': '1.461',
#    'low': '1.33',
#    'vol': '108282.96770919',
#    'volValue': '150836.41499100972',
#    'last': '1.394',
#    'averagePrice': '1.25900081',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'SENSO-USDT',
#    'symbolName': 'SENSO-USDT',
#    'buy': '0.233129',
#    'sell': '0.234252',
#    'changeRate': '-0.0233',
#    'changePrice': '-0.005563',
#    'high': '0.262159',
#    'low': '0.224004',
#    'vol': '1831824.7116076',
#    'volValue': '432556.43599338845296',
#    'last': '0.23312',
#    'averagePrice': '0.25742088',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'ALBT-USDT',
#    'symbolName': 'ALBT-USDT',
#    'buy': '0.09319',
#    'sell': '0.09354',
#    'changeRate': '0.0022',
#    'changePrice': '0.00021',
#    'high': '0.09548',
#    'low': '0.08853',
#    'vol': '580108.37275506',
#    'volValue': '53770.4744838771944',
#    'last': '0.09353',
#    'averagePrice': '0.09072592',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'ALICE-USDT',
#    'symbolName': 'ALICE-USDT',
#    'buy': '2.971',
#    'sell': '2.973',
#    'changeRate': '0.0457',
#    'changePrice': '0.13',
#    'high': '3.043',
#    'low': '2.842',
#    'vol': '152870.93021798',
#    'volValue': '451852.67085083859',
#    'last': '2.972',
#    'averagePrice': '2.87703955',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'GO-USDT',
#    'symbolName': 'GO-USDT',
#    'buy': '0.011595',
#    'sell': '0.011711',
#    'changeRate': '0.0266',
#    'changePrice': '0.000301',
#    'high': '0.012201',
#    'low': '0.011247',
#    'vol': '451823.37222964',
#    'volValue': '5269.27543258199778',
#    'last': '0.011606',
#    'averagePrice': '0.01217933',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'UNIC-USDT',
#    'symbolName': 'UNIC-USDT',
#    'buy': '10.69',
#    'sell': '10.74',
#    'changeRate': '0.018',
#    'changePrice': '0.19',
#    'high': '11.17',
#    'low': '10.37',
#    'vol': '7997.30371948',
#    'volValue': '85205.0259667518',
#    'last': '10.72',
#    'averagePrice': '10.67157348',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'SYS-BTC',
#    'symbolName': 'SYS-BTC',
#    'buy': '0.0000069',
#    'sell': '0.00000709',
#    'changeRate': '0.029',
#    'changePrice': '0.0000002',
#    'high': '0.0000071',
#    'low': '0.00000679',
#    'vol': '14059.1674',
#    'volValue': '0.097894759421',
#    'last': '0.00000709',
#    'averagePrice': '0.0000068',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'PNT-BTC',
#    'symbolName': 'PNT-BTC',
#    'buy': '0.00000768',
#    'sell': '0.0000078',
#    'changeRate': '-0.0051',
#    'changePrice': '-0.00000004',
#    'high': '0.00000805',
#    'low': '0.00000773',
#    'vol': '4322.96579247',
#    'volValue': '0.033934975728914',
#    'last': '0.00000774',
#    'averagePrice': '0.00000777',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'BULL-USDT',
#    'symbolName': 'BULL-USDT',
#    'buy': '0.021079',
#    'sell': '0.021085',
#    'changeRate': '0.0655',
#    'changePrice': '0.001288',
#    'high': '0.037005',
#    'low': '0.017501',
#    'vol': '37228529.64241379',
#    'volValue': '919941.16663006119621',
#    'last': '0.02093',
#    'averagePrice': '0.01828411',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'BOSON-ETH',
#    'symbolName': 'BOSON-ETH',
#    'buy': '0.0002082',
#    'sell': '0.0002093',
#    'changeRate': '0.097',
#    'changePrice': '0.0000185',
#    'high': '0.0002197',
#    'low': '0.000186',
#    'vol': '14437.8228771',
#    'volValue': '2.948574852498605',
#    'last': '0.0002092',
#    'averagePrice': '0.0002109',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'ROOBEE-BTC',
#    'symbolName': 'ROOBEE-BTC',
#    'buy': '0.00000006',
#    'sell': '0.000000062',
#    'changeRate': '0.0892',
#    'changePrice': '0.000000005',
#    'high': '0.000000065',
#    'low': '0.000000056',
#    'vol': '90498183.62416271',
#    'volValue': '5.51483153981349989',
#    'last': '0.000000061',
#    'averagePrice': '0.00000005',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'SWASH-USDT',
#    'symbolName': 'SWASH-USDT',
#    'buy': '0.02235',
#    'sell': '0.02251',
#    'changeRate': '0.004',
#    'changePrice': '0.00009',
#    'high': '0.02354',
#    'low': '0.02141',
#    'vol': '8676443.39265033',
#    'volValue': '196338.7213617035064',
#    'last': '0.02246',
#    'averagePrice': '0.0220475',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'XEC-USDT',
#    'symbolName': 'XEC-USDT',
#    'buy': '0.00004573',
#    'sell': '0.00004585',
#    'changeRate': '0.0065',
#    'changePrice': '0.0000003',
#    'high': '0.00004651',
#    'low': '0.00004499',
#    'vol': '1209963937.05982341',
#    'volValue': '55493.2292581623533075',
#    'last': '0.00004586',
#    'averagePrice': '0.00004405',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'BCH-USDC',
#    'symbolName': 'BCH-USDC',
#    'buy': '192.54',
#    'sell': '192.7',
#    'changeRate': '0.0069',
#    'changePrice': '1.32',
#    'high': '195.22',
#    'low': '189.84',
#    'vol': '575.01548161',
#    'volValue': '110499.1555487408',
#    'last': '192.48',
#    'averagePrice': '200.66914212',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'ATOM3S-USDT',
#    'symbolName': 'ATOM3S-USDT',
#    'buy': '1.4548',
#    'sell': '1.4646',
#    'changeRate': '0.0052',
#    'changePrice': '0.0076',
#    'high': '1.5871',
#    'low': '1.3052',
#    'vol': '65915.70923609',
#    'volValue': '95990.040845433646',
#    'last': '1.4596',
#    'averagePrice': '1.91370368',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'CHSB-BTC',
#    'symbolName': 'CHSB-BTC',
#    'buy': '0.0000105',
#    'sell': '0.00001053',
#    'changeRate': '0.0009',
#    'changePrice': '0.00000001',
#    'high': '0.00001088',
#    'low': '0.0000104',
#    'vol': '19174.9039',
#    'volValue': '0.203838001452',
#    'last': '0.00001053',
#    'averagePrice': '0.00001034',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'LINA-USDT',
#    'symbolName': 'LINA-USDT',
#    'buy': '0.0094',
#    'sell': '0.00942',
#    'changeRate': '0.0755',
#    'changePrice': '0.00066',
#    'high': '0.00973',
#    'low': '0.00855',
#    'vol': '30843940.46402',
#    'volValue': '283942.8913015422005',
#    'last': '0.0094',
#    'averagePrice': '0.00887202',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'ETC-USDT',
#    'symbolName': 'ETC-USDT',
#    'buy': '20.3179',
#    'sell': '20.3312',
#    'changeRate': '0.0084',
#    'changePrice': '0.1707',
#    'high': '20.5598',
#    'low': '20.0581',
#    'vol': '28090.36648223',
#    'volValue': '570226.717109994516',
#    'last': '20.321',
#    'averagePrice': '20.78310834',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'RUNE-USDT',
#    'symbolName': 'RUNE-USDT',
#    'buy': '2.9423',
#    'sell': '2.9445',
#    'changeRate': '0.0395',
#    'changePrice': '0.1121',
#    'high': '3.0103',
#    'low': '2.8243',
#    'vol': '854732.61574885',
#    'volValue': '2503974.026313733378',
#    'last': '2.9457',
#    'averagePrice': '3.28033069',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'TRAC-BTC',
#    'symbolName': 'TRAC-BTC',
#    'buy': '0.00001085',
#    'sell': '0.0000109',
#    'changeRate': '0.052',
#    'changePrice': '0.00000054',
#    'high': '0.00001128',
#    'low': '0.00001026',
#    'vol': '85390.43196661',
#    'volValue': '0.9256258647975883',
#    'last': '0.00001092',
#    'averagePrice': '0.00001011',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'HYDRA-USDT',
#    'symbolName': 'HYDRA-USDT',
#    'buy': '4.057',
#    'sell': '4.062',
#    'changeRate': '-0.0024',
#    'changePrice': '-0.01',
#    'high': '4.099',
#    'low': '4.055',
#    'vol': '11320.10831309',
#    'volValue': '46137.41323212368',
#    'last': '4.057',
#    'averagePrice': '4.07377',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'ASTR-USDT',
#    'symbolName': 'ASTR-USDT',
#    'buy': '0.0572',
#    'sell': '0.0573',
#    'changeRate': '0.0232',
#    'changePrice': '0.0013',
#    'high': '0.0593',
#    'low': '0.0547',
#    'vol': '3603059.37615552',
#    'volValue': '205310.681396938617',
#    'last': '0.0572',
#    'averagePrice': '0.06796194',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'WBTC-ETH',
#    'symbolName': 'WBTC-ETH',
#    'buy': '14.8667',
#    'sell': '14.9065',
#    'changeRate': '0.0004',
#    'changePrice': '0.0066',
#    'high': '14.9304',
#    'low': '14.8176',
#    'vol': '0.0614',
#    'volValue': '0.91378829',
#    'last': '14.8658',
#    'averagePrice': '14.76338931',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'BCH-USDT',
#    'symbolName': 'BCH-USDT',
#    'buy': '192.92',
#    'sell': '192.96',
#    'changeRate': '0.0074',
#    'changePrice': '1.42',
#    'high': '195.76',
#    'low': '189.91',
#    'vol': '8048.86243578',
#    'volValue': '1550302.5920076366',
#    'last': '192.87',
#    'averagePrice': '201.64718312',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'NGM-USDT',
#    'symbolName': 'NGM-USDT',
#    'buy': '0.9008',
#    'sell': '0.9042',
#    'changeRate': '0.0129',
#    'changePrice': '0.0115',
#    'high': '0.9042',
#    'low': '0.8877',
#    'vol': '278584.09790501',
#    'volValue': '249391.026424520042',
#    'last': '0.9022',
#    'averagePrice': '0.94701981',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'JAR-USDT',
#    'symbolName': 'JAR-USDT',
#    'buy': '0.001647',
#    'sell': '0.001667',
#    'changeRate': '-0.0213',
#    'changePrice': '-0.000036',
#    'high': '0.002077',
#    'low': '0.001576',
#    'vol': '19551133.27718922',
#    'volValue': '34879.05174618111723',
#    'last': '0.001652',
#    'averagePrice': '0.0016103',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'TONE-USDT',
#    'symbolName': 'TONE-USDT',
#    'buy': '0.01018',
#    'sell': '0.01041',
#    'changeRate': '-0.0392',
#    'changePrice': '-0.00042',
#    'high': '0.01114',
#    'low': '0.00999',
#    'vol': '3157838.62718525',
#    'volValue': '33008.377275285621',
#    'last': '0.01028',
#    'averagePrice': '0.00986911',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'POSI-USDT',
#    'symbolName': 'POSI-USDT',
#    'buy': '0.3467',
#    'sell': '0.3482',
#    'changeRate': '0.0266',
#    'changePrice': '0.009',
#    'high': '0.36',
#    'low': '0.333',
#    'vol': '532983.89629801',
#    'volValue': '181779.735398605659',
#    'last': '0.3465',
#    'averagePrice': '0.32422809',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'XDB-BTC',
#    'symbolName': 'XDB-BTC',
#    'buy': '0.0000048',
#    'sell': '0.00000484',
#    'changeRate': '0.0547',
#    'changePrice': '0.00000025',
#    'high': '0.00000495',
#    'low': '0.00000454',
#    'vol': '213766.26991535',
#    'volValue': '1.0056103390574292',
#    'last': '0.00000482',
#    'averagePrice': '0.00000452',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'EOS3L-USDT',
#    'symbolName': 'EOS3L-USDT',
#    'buy': '7.712291',
#    'sell': '7.789147',
#    'changeRate': '0.1162',
#    'changePrice': '0.816637',
#    'high': '7.84185',
#    'low': '7.000001',
#    'vol': '1915.813199',
#    'volValue': '14250.07951812755677',
#    'last': '7.84185',
#    'averagePrice': '0.00161458',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'HYVE-BTC',
#    'symbolName': 'HYVE-BTC',
#    'buy': '0.00000226',
#    'sell': '0.00000227',
#    'changeRate': '-0.034',
#    'changePrice': '-0.00000008',
#    'high': '0.00000235',
#    'low': '0.00000226',
#    'vol': '790099.4443',
#    'volValue': '1.810300299779',
#    'last': '0.00000227',
#    'averagePrice': '0.0000023',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'KAVA-USDT',
#    'symbolName': 'KAVA-USDT',
#    'buy': '2.7517',
#    'sell': '2.7541',
#    'changeRate': '0.0791',
#    'changePrice': '0.202',
#    'high': '2.8875',
#    'low': '2.5297',
#    'vol': '789389.42880806',
#    'volValue': '2159121.639524270551',
#    'last': '2.7532',
#    'averagePrice': '2.33257476',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'GLQ-USDT',
#    'symbolName': 'GLQ-USDT',
#    'buy': '0.00349',
#    'sell': '0.00356',
#    'changeRate': '-0.0028',
#    'changePrice': '-0.00001',
#    'high': '0.00375',
#    'low': '0.00346',
#    'vol': '2983432.63107983',
#    'volValue': '10763.5060002108327',
#    'last': '0.00356',
#    'averagePrice': '0.00374697',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'SHX-BTC',
#    'symbolName': 'SHX-BTC',
#    'buy': '0.0000000539',
#    'sell': '0.0000000541',
#    'changeRate': '0.0093',
#    'changePrice': '0.0000000005',
#    'high': '0.0000000551',
#    'low': '0.0000000525',
#    'vol': '479192.451',
#    'volValue': '0.0259117274668',
#    'last': '0.0000000542',
#    'averagePrice': '0.00000005',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'VSYS-USDT',
#    'symbolName': 'VSYS-USDT',
#    'buy': '0.00465',
#    'sell': '0.00469',
#    'changeRate': '0.0608',
#    'changePrice': '0.00027',
#    'high': '0.00471',
#    'low': '0.00439',
#    'vol': '905116.15176992',
#    'volValue': '4083.6157690609481',
#    'last': '0.00471',
#    'averagePrice': '0.00435849',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'TKO-BTC',
#    'symbolName': 'TKO-BTC',
#    'buy': '0.00001275',
#    'sell': '0.00001288',
#    'changeRate': '0.0007',
#    'changePrice': '0.00000001',
#    'high': '0.00001338',
#    'low': '0.00001254',
#    'vol': '2884.22499603',
#    'volValue': '0.0370696264888986',
#    'last': '0.00001282',
#    'averagePrice': '0.0000122',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'ETH-DAI',
#    'symbolName': 'ETH-DAI',
#    'buy': '1965.02',
#    'sell': '1972.85',
#    'changeRate': '-0.0033',
#    'changePrice': '-6.63',
#    'high': '2062.38',
#    'low': '1954.06',
#    'vol': '49.76674499',
#    'volValue': '98827.5151533048',
#    'last': '1969.01',
#    'averagePrice': '2035.89458033',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'REQ-BTC',
#    'symbolName': 'REQ-BTC',
#    'buy': '0.00000384',
#    'sell': '0.00000387',
#    'changeRate': '-0.0051',
#    'changePrice': '-0.00000002',
#    'high': '0.00000394',
#    'low': '0.00000377',
#    'vol': '66769.92848137',
#    'volValue': '0.2574434551539238',
#    'last': '0.00000385',
#    'averagePrice': '0.00000376',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'GOM2-BTC',
#    'symbolName': 'GOM2-BTC',
#    'buy': '0.00000073',
#    'sell': '0.0000008',
#    'changeRate': '0.0129',
#    'changePrice': '0.00000001',
#    'high': '0.00000078',
#    'low': '0.00000074',
#    'vol': '16499.44876153',
#    'volValue': '0.0125382413769934',
#    'last': '0.00000078',
#    'averagePrice': '0.00000079',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'PIVX-BTC',
#    'symbolName': 'PIVX-BTC',
#    'buy': '0.00000418',
#    'sell': '0.00000419',
#    'changeRate': '-0.0187',
#    'changePrice': '-0.00000008',
#    'high': '0.00000553',
#    'low': '0.00000416',
#    'vol': '306274.26497002',
#    'volValue': '1.4486456531282613',
#    'last': '0.00000418',
#    'averagePrice': '0.0000041',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'GAS-USDT',
#    'symbolName': 'GAS-USDT',
#    'buy': '2.4099',
#    'sell': '2.4378',
#    'changeRate': '0.0185',
#    'changePrice': '0.0438',
#    'high': '2.4534',
#    'low': '2.2537',
#    'vol': '4902.75992923',
#    'volValue': '11582.400026837246',
#    'last': '2.4044',
#    'averagePrice': '2.48605249',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'TRX-USDT',
#    'symbolName': 'TRX-USDT',
#    'buy': '0.074314',
#    'sell': '0.074318',
#    'changeRate': '0.0413',
#    'changePrice': '0.002948',
#    'high': '0.075874',
#    'low': '0.071359',
#    'vol': '134883657.75626436',
#    'volValue': '9925416.19500948727175',
#    'last': '0.074307',
#    'averagePrice': '0.07189243',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'CELO-USDT',
#    'symbolName': 'CELO-USDT',
#    'buy': '1.3008',
#    'sell': '1.303',
#    'changeRate': '0.0218',
#    'changePrice': '0.0278',
#    'high': '1.3338',
#    'low': '1.2534',
#    'vol': '341379.67202125',
#    'volValue': '442149.378330806628',
#    'last': '1.3017',
#    'averagePrice': '1.43267913',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'ENJ-BTC',
#    'symbolName': 'ENJ-BTC',
#    'buy': '0.00002354',
#    'sell': '0.00002358',
#    'changeRate': '0.037',
#    'changePrice': '0.00000084',
#    'high': '0.00002401',
#    'low': '0.00002265',
#    'vol': '19872.99425326',
#    'volValue': '0.4640921242589902',
#    'last': '0.00002353',
#    'averagePrice': '0.0000235',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'NEO-KCS',
#    'symbolName': 'NEO-KCS',
#    'buy': '0.645',
#    'sell': '0.646',
#    'changeRate': '0.0015',
#    'changePrice': '0.001',
#    'high': '0.668',
#    'low': '0.637',
#    'vol': '299.554971',
#    'volValue': '195.456264206',
#    'last': '0.645',
#    'averagePrice': '0.74011012',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'VET-KCS',
#    'symbolName': 'VET-KCS',
#    'buy': '0.001915',
#    'sell': '0.001921',
#    'changeRate': '0',
#    'changePrice': '0',
#    'high': '0.00196',
#    'low': '0.001898',
#    'vol': '460281.87226606',
#    'volValue': '887.99224306378045',
#    'last': '0.001917',
#    'averagePrice': '0.00231893',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'SAND-USDT',
#    'symbolName': 'SAND-USDT',
#    'buy': '1.33238',
#    'sell': '1.33287',
#    'changeRate': '0.0523',
#    'changePrice': '0.06626',
#    'high': '1.39158',
#    'low': '1.26314',
#    'vol': '4150263.23106134',
#    'volValue': '5474530.7463252110016',
#    'last': '1.33228',
#    'averagePrice': '1.32732233',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'KLAY-USDT',
#    'symbolName': 'KLAY-USDT',
#    'buy': '0.4655',
#    'sell': '0.4667',
#    'changeRate': '0.1148',
#    'changePrice': '0.0479',
#    'high': '0.4716',
#    'low': '0.4171',
#    'vol': '172211.31202555',
#    'volValue': '77662.427166954497',
#    'last': '0.465',
#    'averagePrice': '0.40584703',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'T-USDT',
#    'symbolName': 'T-USDT',
#    'buy': '0.0485',
#    'sell': '0.0487',
#    'changeRate': '0.002',
#    'changePrice': '0.0001',
#    'high': '0.0493',
#    'low': '0.0481',
#    'vol': '110907.39561564',
#    'volValue': '5380.227186690153',
#    'last': '0.0485',
#    'averagePrice': '0.05291579',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'SUN-USDT',
#    'symbolName': 'SUN-USDT',
#    'buy': '0.00881',
#    'sell': '0.00882',
#    'changeRate': '0.0184',
#    'changePrice': '0.00016',
#    'high': '0.00909',
#    'low': '0.00863',
#    'vol': '73753976.79572633',
#    'volValue': '651105.3096696923411',
#    'last': '0.00881',
#    'averagePrice': '0.00895279',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'PUSH-BTC',
#    'symbolName': 'PUSH-BTC',
#    'buy': '0.00001807',
#    'sell': '0.00001815',
#    'changeRate': '0.014',
#    'changePrice': '0.00000025',
#    'high': '0.00001815',
#    'low': '0.0000175',
#    'vol': '2339.6021',
#    'volValue': '0.041732031842',
#    'last': '0.0000181',
#    'averagePrice': '0.00001913',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'PERP-BTC',
#    'symbolName': 'PERP-BTC',
#    'buy': '0.0000382',
#    'sell': '0.0000385',
#    'changeRate': '0.0379',
#    'changePrice': '0.0000014',
#    'high': '0.0000433',
#    'low': '0.0000366',
#    'vol': '22813.4103',
#    'volValue': '0.92182914322',
#    'last': '0.0000383',
#    'averagePrice': '0.00003938',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'DATA-USDT',
#    'symbolName': 'DATA-USDT',
#    'buy': '0.0353',
#    'sell': '0.0356',
#    'changeRate': '-0.0028',
#    'changePrice': '-0.0001',
#    'high': '0.0372',
#    'low': '0.0347',
#    'vol': '1312964.12270227',
#    'volValue': '47056.739569895437',
#    'last': '0.0353',
#    'averagePrice': '0.03476074',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'ELF-ETH',
#    'symbolName': 'ELF-ETH',
#    'buy': '0.00008',
#    'sell': '0.0000832',
#    'changeRate': '0.0986',
#    'changePrice': '0.0000074',
#    'high': '0.0000824',
#    'low': '0.000075',
#    'vol': '8149.7184',
#    'volValue': '0.6303513985',
#    'last': '0.0000824',
#    'averagePrice': '0.00007684',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'NGL-BTC',
#    'symbolName': 'NGL-BTC',
#    'buy': '0.00001531',
#    'sell': '0.00001617',
#    'changeRate': '-0.0362',
#    'changePrice': '-0.00000058',
#    'high': '0.00001807',
#    'low': '0.00001519',
#    'vol': '264.7579',
#    'volValue': '0.004240946599',
#    'last': '0.0000154',
#    'averagePrice': '0.00001749',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'KLAY-BTC',
#    'symbolName': 'KLAY-BTC',
#    'buy': '0.00001579',
#    'sell': '0.00001585',
#    'changeRate': '0.1067',
#    'changePrice': '0.00000152',
#    'high': '0.00001596',
#    'low': '0.00001424',
#    'vol': '5282.68806966',
#    'volValue': '0.0793694164817565',
#    'last': '0.00001576',
#    'averagePrice': '0.00001372',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'POWR-BTC',
#    'symbolName': 'POWR-BTC',
#    'buy': '0.00000891',
#    'sell': '0.00000896',
#    'changeRate': '0.0596',
#    'changePrice': '0.0000005',
#    'high': '0.00000945',
#    'low': '0.00000837',
#    'vol': '45146.124859',
#    'volValue': '0.40679149887215',
#    'last': '0.00000888',
#    'averagePrice': '0.00000829',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'CTC-BTC',
#    'symbolName': 'CTC-BTC',
#    'buy': '0.0000192',
#    'sell': '0.0000194',
#    'changeRate': '-0.1312',
#    'changePrice': '-0.0000029',
#    'high': '0.00002352',
#    'low': '0.00001918',
#    'vol': '24330.9877',
#    'volValue': '0.507290446025',
#    'last': '0.0000192',
#    'averagePrice': '0.00002165',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'LABS-USDT',
#    'symbolName': 'LABS-USDT',
#    'buy': '0.001302',
#    'sell': '0.001308',
#    'changeRate': '0.0132',
#    'changePrice': '0.000017',
#    'high': '0.001352',
#    'low': '0.001279',
#    'vol': '19640313.85375236',
#    'volValue': '25929.40982601404137',
#    'last': '0.001301',
#    'averagePrice': '0.00137055',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'ETC-ETH',
#    'symbolName': 'ETC-ETH',
#    'buy': '0.010289',
#    'sell': '0.010302',
#    'changeRate': '0.0012',
#    'changePrice': '0.000013',
#    'high': '0.010377',
#    'low': '0.010202',
#    'vol': '415.88810027',
#    'volValue': '4.27319653265914',
#    'last': '0.010277',
#    'averagePrice': '0.01021967',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'BOND-USDT',
#    'symbolName': 'BOND-USDT',
#    'buy': '3.42',
#    'sell': '3.45',
#    'changeRate': '0.0058',
#    'changePrice': '0.02',
#    'high': '3.66',
#    'low': '3.42',
#    'vol': '3468.67107081',
#    'volValue': '12176.2658889414',
#    'last': '3.44',
#    'averagePrice': '3.51936531',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'XMR-ETH',
#    'symbolName': 'XMR-ETH',
#    'buy': '0.08766',
#    'sell': '0.08795',
#    'changeRate': '0.0057',
#    'changePrice': '0.0005',
#    'high': '0.09147',
#    'low': '0.08689',
#    'vol': '1005.3758959',
#    'volValue': '89.5578570097449',
#    'last': '0.08782',
#    'averagePrice': '0.08095795',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'LTC3S-USDT',
#    'symbolName': 'LTC3S-USDT',
#    'buy': '1.5457',
#    'sell': '1.5504',
#    'changeRate': '-0.0361',
#    'changePrice': '-0.058',
#    'high': '1.6796',
#    'low': '1.3923',
#    'vol': '71449.71853103',
#    'volValue': '110958.251583540165',
#    'last': '1.5457',
#    'averagePrice': '1.82695201',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'DPET-USDT',
#    'symbolName': 'DPET-USDT',
#    'buy': '0.1932',
#    'sell': '0.1933',
#    'changeRate': '0.0404',
#    'changePrice': '0.0075',
#    'high': '0.2036',
#    'low': '0.1794',
#    'vol': '244520.9265332',
#    'volValue': '45837.52922107482',
#    'last': '0.1929',
#    'averagePrice': '0.18290491',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'TARA-USDT',
#    'symbolName': 'TARA-USDT',
#    'buy': '0.002167',
#    'sell': '0.002179',
#    'changeRate': '0.0358',
#    'changePrice': '0.000075',
#    'high': '0.002352',
#    'low': '0.00202',
#    'vol': '26321802.25463728',
#    'volValue': '57789.73627441318673',
#    'last': '0.002167',
#    'averagePrice': '0.00208018',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'DERO-USDT',
#    'symbolName': 'DERO-USDT',
#    'buy': '5.34317',
#    'sell': '5.40498',
#    'changeRate': '-0.0436',
#    'changePrice': '-0.24384',
#    'high': '5.6622',
#    'low': '5.1504',
#    'vol': '11513.15859108',
#    'volValue': '62184.9074737764137',
#    'last': '5.34851',
#    'averagePrice': '6.48823079',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'EFX-USDT',
#    'symbolName': 'EFX-USDT',
#    'buy': '0.00447',
#    'sell': '0.00448',
#    'changeRate': '0.0323',
#    'changePrice': '0.00014',
#    'high': '0.00467',
#    'low': '0.00432',
#    'vol': '17571003.43317453',
#    'volValue': '78340.6205551529705',
#    'last': '0.00447',
#    'averagePrice': '0.00448042',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'RLC-BTC',
#    'symbolName': 'RLC-BTC',
#    'buy': '0.00003069',
#    'sell': '0.00003085',
#    'changeRate': '0.0013',
#    'changePrice': '0.00000004',
#    'high': '0.00003197',
#    'low': '0.00002978',
#    'vol': '5619.13925286',
#    'volValue': '0.1753942261777586',
#    'last': '0.00003055',
#    'averagePrice': '0.00002837',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'MATIC-BTC',
#    'symbolName': 'MATIC-BTC',
#    'buy': '0.00002201',
#    'sell': '0.00002203',
#    'changeRate': '0.0166',
#    'changePrice': '0.00000036',
#    'high': '0.00002237',
#    'low': '0.0000206',
#    'vol': '320426.62358214',
#    'volValue': '7.0409459571314087',
#    'last': '0.00002202',
#    'averagePrice': '0.00002255',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'ALICE-ETH',
#    'symbolName': 'ALICE-ETH',
#    'buy': '0.001502',
#    'sell': '0.001509',
#    'changeRate': '0.038',
#    'changePrice': '0.000055',
#    'high': '0.001529',
#    'low': '0.001447',
#    'vol': '151.8271',
#    'volValue': '0.2263299612',
#    'last': '0.001502',
#    'averagePrice': '0.00138349',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'YFI-UST',
#    'symbolName': 'YFI-UST',
#    'buy': '127294.58',
#    'sell': '132304.57',
#    'changeRate': '-0.1571',
#    'changePrice': '-24480.56',
#    'high': '197117.29',
#    'low': '123665.49',
#    'vol': '0.87498926',
#    'volValue': '130735.3773114858',
#    'last': '131280.11',
#    'averagePrice': '101251.16256329',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'WOM-USDT',
#    'symbolName': 'WOM-USDT',
#    'buy': '0.052888',
#    'sell': '0.053338',
#    'changeRate': '-0.0094',
#    'changePrice': '-0.000511',
#    'high': '0.056343',
#    'low': '0.052552',
#    'vol': '1720849.57953045',
#    'volValue': '94629.3195948664969',
#    'last': '0.053338',
#    'averagePrice': '0.05569219',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'NUM-USDT',
#    'symbolName': 'NUM-USDT',
#    'buy': '0.1033',
#    'sell': '0.104',
#    'changeRate': '0.0966',
#    'changePrice': '0.0091',
#    'high': '0.1073',
#    'low': '0.0936',
#    'vol': '777648.32536431',
#    'volValue': '77505.663080560817',
#    'last': '0.1033',
#    'averagePrice': '0.11169723',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'NMR-USDT',
#    'symbolName': 'NMR-USDT',
#    'buy': '12.817',
#    'sell': '12.841',
#    'changeRate': '0.0143',
#    'changePrice': '0.183',
#    'high': '13.156',
#    'low': '12.705',
#    'vol': '584.0008',
#    'volValue': '7538.2761504',
#    'last': '12.893',
#    'averagePrice': '13.29380131',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'WAX-BTC',
#    'symbolName': 'WAX-BTC',
#    'buy': '0.00000443',
#    'sell': '0.00000445',
#    'changeRate': '0.0698',
#    'changePrice': '0.00000029',
#    'high': '0.00000464',
#    'low': '0.00000414',
#    'vol': '99679.90477081',
#    'volValue': '0.4360529320449521',
#    'last': '0.00000444',
#    'averagePrice': '0.00000388',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'DOGE-USDC',
#    'symbolName': 'DOGE-USDC',
#    'buy': '0.08416',
#    'sell': '0.08422',
#    'changeRate': '0.0047',
#    'changePrice': '0.0004',
#    'high': '0.08522',
#    'low': '0.08365',
#    'vol': '687927.76886545',
#    'volValue': '58060.0135492215963',
#    'last': '0.0842',
#    'averagePrice': '0.08767058',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'CWAR-USDT',
#    'symbolName': 'CWAR-USDT',
#    'buy': '0.0606',
#    'sell': '0.061',
#    'changeRate': '0.1673',
#    'changePrice': '0.0087',
#    'high': '0.0695',
#    'low': '0.0517',
#    'vol': '7683487.97354285',
#    'volValue': '459796.153504449263',
#    'last': '0.0607',
#    'averagePrice': '0.05172133',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '3',
#    'makerCoefficient': '3'},
#   {'symbol': 'AAVE-USDT',
#    'symbolName': 'AAVE-USDT',
#    'buy': '93.502',
#    'sell': '93.694',
#    'changeRate': '0.0298',
#    'changePrice': '2.715',
#    'high': '93.82',
#    'low': '88.96',
#    'vol': '11490.54134774',
#    'volValue': '1049960.05186443005',
#    'last': '93.574',
#    'averagePrice': '87.89003178',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'EWT-KCS',
#    'symbolName': 'EWT-KCS',
#    'buy': '0.1782',
#    'sell': '0.1796',
#    'changeRate': '0.027',
#    'changePrice': '0.0047',
#    'high': '0.1864',
#    'low': '0.1727',
#    'vol': '907.82943423',
#    'volValue': '163.154871600667',
#    'last': '0.1782',
#    'averagePrice': '0.21818754',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'AAVE3S-USDT',
#    'symbolName': 'AAVE3S-USDT',
#    'buy': '2.5341',
#    'sell': '2.5446',
#    'changeRate': '-0.0755',
#    'changePrice': '-0.2072',
#    'high': '2.936',
#    'low': '2.52',
#    'vol': '37819.5662604',
#    'volValue': '100524.138598819743',
#    'last': '2.5341',
#    'averagePrice': '3.82340316',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'CREDI-USDT',
#    'symbolName': 'CREDI-USDT',
#    'buy': '0.00315',
#    'sell': '0.0032',
#    'changeRate': '-0.0724',
#    'changePrice': '-0.00025',
#    'high': '0.0035',
#    'low': '0.00303',
#    'vol': '23406326.95024918',
#    'volValue': '76943.9406076552262',
#    'last': '0.0032',
#    'averagePrice': '0.00319829',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'LON-USDT',
#    'symbolName': 'LON-USDT',
#    'buy': '0.866',
#    'sell': '0.8731',
#    'changeRate': '0.0073',
#    'changePrice': '0.0063',
#    'high': '0.879',
#    'low': '0.8521',
#    'vol': '2923.27941019',
#    'volValue': '2540.207130298538',
#    'last': '0.8613',
# ...
#    'changePrice': '0.0000000081',
#    'high': '0.0000001985',
#    'low': '0.0000001569',
#    'vol': '2446091.06263666',
#    'volValue': '0.425242087934789206',
#    'last': '0.0000001659',
#    'averagePrice': '0.00000016',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'GO-BTC',
#    'symbolName': 'GO-BTC',
#    'buy': '0.00000039',
#    'sell': '0.0000004',
#    'changeRate': '0',
#    'changePrice': '0',
#    'high': '0.00000044',
#    'low': '0.00000038',
#    'vol': '169070.37304203',
#    'volValue': '0.0677550010726239',
#    'last': '0.00000039',
#    'averagePrice': '0.0000004',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'AVAX3L-USDT',
#    'symbolName': 'AVAX3L-USDT',
#    'buy': '0.010424',
#    'sell': '0.010446',
#    'changeRate': '0.0728',
#    'changePrice': '0.000709',
#    'high': '0.011367',
#    'low': '0.0093',
#    'vol': '24314535.95670289',
#    'volValue': '249905.89570117267179',
#    'last': '0.010446',
#    'averagePrice': '0.01393795',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'XVS-USDT',
#    'symbolName': 'XVS-USDT',
#    'buy': '4.758',
#    'sell': '4.761',
#    'changeRate': '-0.0137',
#    'changePrice': '-0.066',
#    'high': '5.255',
#    'low': '4.71',
#    'vol': '16021.76476293',
#    'volValue': '77332.66294333301',
#    'last': '4.738',
#    'averagePrice': '5.32554684',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'SPI-USDT',
#    'symbolName': 'SPI-USDT',
#    'buy': '4.344',
#    'sell': '4.503',
#    'changeRate': '0.0775',
#    'changePrice': '0.311',
#    'high': '4.579',
#    'low': '4.012',
#    'vol': '1359.45972499',
#    'volValue': '5928.69312828746',
#    'last': '4.323',
#    'averagePrice': '4.53405314',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'LTC-BTC',
#    'symbolName': 'LTC-BTC',
#    'buy': '0.002382',
#    'sell': '0.002384',
#    'changeRate': '0.008',
#    'changePrice': '0.000019',
#    'high': '0.002387',
#    'low': '0.002356',
#    'vol': '2170.92945346',
#    'volValue': '5.14643930570396',
#    'last': '0.002384',
#    'averagePrice': '0.00231816',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'GHST-BTC',
#    'symbolName': 'GHST-BTC',
#    'buy': '0.00005253',
#    'sell': '0.0000532',
#    'changeRate': '-0.005',
#    'changePrice': '-0.00000027',
#    'high': '0.00005374',
#    'low': '0.0000513',
#    'vol': '795.099',
#    'volValue': '0.041778089411',
#    'last': '0.00005317',
#    'averagePrice': '0.00005314',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'DGB-USDT',
#    'symbolName': 'DGB-USDT',
#    'buy': '0.012267',
#    'sell': '0.012295',
#    'changeRate': '0.0467',
#    'changePrice': '0.000548',
#    'high': '0.012653',
#    'low': '0.01169',
#    'vol': '32740337.60897115',
#    'volValue': '400900.03788607206134',
#    'last': '0.012267',
#    'averagePrice': '0.01229332',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'LRC-USDT',
#    'symbolName': 'LRC-USDT',
#    'buy': '0.4907',
#    'sell': '0.4909',
#    'changeRate': '0.0127',
#    'changePrice': '0.0062',
#    'high': '0.4999',
#    'low': '0.4757',
#    'vol': '2639407.80821551',
#    'volValue': '1290114.685375038843',
#    'last': '0.4907',
#    'averagePrice': '0.47759164',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'EDG-USDT',
#    'symbolName': 'EDG-USDT',
#    'buy': '0.002707',
#    'sell': '0.002713',
#    'changeRate': '-0.008',
#    'changePrice': '-0.000022',
#    'high': '0.002798',
#    'low': '0.002599',
#    'vol': '7956088.01728166',
#    'volValue': '21780.76482052951235',
#    'last': '0.002716',
#    'averagePrice': '0.00265597',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'VOXEL-ETH',
#    'symbolName': 'VOXEL-ETH',
#    'buy': '0.0003351',
#    'sell': '0.0003437',
#    'changeRate': '0.0648',
#    'changePrice': '0.0000211',
#    'high': '0.0003464',
#    'low': '0.0003023',
#    'vol': '23762.84767143',
#    'volValue': '7.676093698277612',
#    'last': '0.0003464',
#    'averagePrice': '0.00029237',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'GRIN-USDT',
#    'symbolName': 'GRIN-USDT',
#    'buy': '0.141993',
#    'sell': '0.1424',
#    'changeRate': '-0.0154',
#    'changePrice': '-0.002226',
#    'high': '0.176776',
#    'low': '0.139316',
#    'vol': '644885.35415876',
#    'volValue': '101052.13927864924245',
#    'last': '0.141993',
#    'averagePrice': '0.23922909',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'QTUM-BTC',
#    'symbolName': 'QTUM-BTC',
#    'buy': '0.00013431',
#    'sell': '0.00013514',
#    'changeRate': '0.0229',
#    'changePrice': '0.00000302',
#    'high': '0.00013522',
#    'low': '0.00013105',
#    'vol': '1873.11803267',
#    'volValue': '0.2501248944840861',
#    'last': '0.00013484',
#    'averagePrice': '0.00013358',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'MSWAP-BTC',
#    'symbolName': 'MSWAP-BTC',
#    'buy': '0.00000002',
#    'sell': '0.00000003',
#    'changeRate': '0',
#    'changePrice': '0',
#    'high': '0.00000003',
#    'low': '0.00000002',
#    'vol': '33334786.53723326',
#    'volValue': '0.6707785974789978',
#    'last': '0.00000002',
#    'averagePrice': '0.00000001',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'REEF-USDT',
#    'symbolName': 'REEF-USDT',
#    'buy': '0.00445',
#    'sell': '0.00446',
#    'changeRate': '0.0276',
#    'changePrice': '0.00012',
#    'high': '0.00465',
#    'low': '0.00429',
#    'vol': '25446629.16481312',
#    'volValue': '112249.6044603475743',
#    'last': '0.00446',
#    'averagePrice': '0.00447074',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'ANKR-USDT',
#    'symbolName': 'ANKR-USDT',
#    'buy': '0.03932',
#    'sell': '0.03933',
#    'changeRate': '0.0693',
#    'changePrice': '0.00255',
#    'high': '0.0398',
#    'low': '0.03666',
#    'vol': '5871571.99718768',
#    'volValue': '224768.3381091461627',
#    'last': '0.03934',
#    'averagePrice': '0.03775409',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'PEL-USDT',
#    'symbolName': 'PEL-USDT',
#    'buy': '0.0231',
#    'sell': '0.0233',
#    'changeRate': '-0.1245',
#    'changePrice': '-0.0033',
#    'high': '0.04',
#    'low': '0.0224',
#    'vol': '12548696.65193631',
#    'volValue': '331522.972778774529',
#    'last': '0.0232',
#    'averagePrice': '0.02479298',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'CLH-USDT',
#    'symbolName': 'CLH-USDT',
#    'buy': '0.02405',
#    'sell': '0.02409',
#    'changeRate': '-0.009',
#    'changePrice': '-0.00022',
#    'high': '0.0267',
#    'low': '0.02403',
#    'vol': '99796946.96027697',
#    'volValue': '2519600.5147169724129',
#    'last': '0.02409',
#    'averagePrice': '0.02379925',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '3',
#    'makerCoefficient': '3'},
#   {'symbol': 'SUSD-BTC',
#    'symbolName': 'SUSD-BTC',
#    'buy': '0.00003322',
#    'sell': '0.00003436',
#    'changeRate': '-0.0133',
#    'changePrice': '-0.00000045',
#    'high': '0.00003479',
#    'low': '0.00003237',
#    'vol': '28.5855',
#    'volValue': '0.000964689298',
#    'last': '0.00003323',
#    'averagePrice': '0.00003341',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'DAPPX-USDT',
#    'symbolName': 'DAPPX-USDT',
#    'buy': '0.00954',
#    'sell': '0.0096',
#    'changeRate': '0.0268',
#    'changePrice': '0.00025',
#    'high': '0.00992',
#    'low': '0.00911',
#    'vol': '32173404.87952793',
#    'volValue': '305422.2048976281567',
#    'last': '0.00955',
#    'averagePrice': '0.00869298',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'OUSD-BTC',
#    'symbolName': 'OUSD-BTC',
#    'buy': '0.000034',
#    'sell': '0.00003415',
#    'changeRate': '-0.0038',
#    'changePrice': '-0.00000013',
#    'high': '0.00003431',
#    'low': '0.00003375',
#    'vol': '107419.2273',
#    'volValue': '3.655956850563',
#    'last': '0.00003408',
#    'averagePrice': '0.00003359',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'DYP-ETH',
#    'symbolName': 'DYP-ETH',
#    'buy': '0.00004',
#    'sell': '0.000041',
#    'changeRate': '0.1081',
#    'changePrice': '0.000004',
#    'high': '0.000041',
#    'low': '0.000037',
#    'vol': '1614322.8645',
#    'volValue': '64.7912885986',
#    'last': '0.000041',
#    'averagePrice': '0.00003646',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'FLY-USDT',
#    'symbolName': 'FLY-USDT',
#    'buy': '0.001186',
#    'sell': '0.001197',
#    'changeRate': '0.0338',
#    'changePrice': '0.000039',
#    'high': '0.001278',
#    'low': '0.001114',
#    'vol': '16021665.98606873',
#    'volValue': '18955.4597990674129',
#    'last': '0.001192',
#    'averagePrice': '0.00102379',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'PLAY-BTC',
#    'symbolName': 'PLAY-BTC',
#    'buy': '0.0000002395',
#    'sell': '0.0000002414',
#    'changeRate': '0.1254',
#    'changePrice': '0.0000000267',
#    'high': '0.000000262',
#    'low': '0.0000002089',
#    'vol': '1631780.0686',
#    'volValue': '0.3886608299046',
#    'last': '0.0000002395',
#    'averagePrice': '0.00000022',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'ROUTE-USDT',
#    'symbolName': 'ROUTE-USDT',
#    'buy': '1.968',
#    'sell': '1.9732',
#    'changeRate': '0.0839',
#    'changePrice': '0.1528',
#    'high': '2.06',
#    'low': '1.798',
#    'vol': '71773.90527516',
#    'volValue': '138027.480681554157',
#    'last': '1.9738',
#    'averagePrice': '1.67066098',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'BAKE-USDT',
#    'symbolName': 'BAKE-USDT',
#    'buy': '0.2832',
#    'sell': '0.2836',
#    'changeRate': '0.0627',
#    'changePrice': '0.0167',
#    'high': '0.2856',
#    'low': '0.2662',
#    'vol': '520354.78517321',
#    'volValue': '144684.410997741654',
#    'last': '0.2829',
#    'averagePrice': '0.27348872',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'BOBA-USDT',
#    'symbolName': 'BOBA-USDT',
#    'buy': '0.475',
#    'sell': '0.4762',
#    'changeRate': '0.054',
#    'changePrice': '0.0244',
#    'high': '0.5169',
#    'low': '0.4515',
#    'vol': '35396.86195301',
#    'volValue': '16912.814643266859',
#    'last': '0.4759',
#    'averagePrice': '0.46441501',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'MAP-BTC',
#    'symbolName': 'MAP-BTC',
#    'buy': '0.0000004515',
#    'sell': '0.0000004594',
#    'changeRate': '0.0316',
#    'changePrice': '0.0000000141',
#    'high': '0.0000004598',
#    'low': '0.0000004444',
#    'vol': '3356888.24074708',
#    'volValue': '1.518877055142317932',
#    'last': '0.0000004594',
#    'averagePrice': '0.00000043',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'ORN-USDT',
#    'symbolName': 'ORN-USDT',
#    'buy': '1.383',
#    'sell': '1.3929',
#    'changeRate': '0.0192',
#    'changePrice': '0.0263',
#    'high': '1.4164',
#    'low': '1.3475',
#    'vol': '48010.16561352',
#    'volValue': '66280.496920610206',
#    'last': '1.3916',
#    'averagePrice': '1.44496479',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'FLOW-BTC',
#    'symbolName': 'FLOW-BTC',
#    'buy': '0.0000953',
#    'sell': '0.0000955',
#    'changeRate': '0.0192',
#    'changePrice': '0.0000018',
#    'high': '0.0000963',
#    'low': '0.0000934',
#    'vol': '3293.38264282',
#    'volValue': '0.312377573658682',
#    'last': '0.0000954',
#    'averagePrice': '0.00009875',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'SLIM-USDT',
#    'symbolName': 'SLIM-USDT',
#    'buy': '0.139',
#    'sell': '0.142',
#    'changeRate': '0.0072',
#    'changePrice': '0.001',
#    'high': '0.157',
#    'low': '0.135',
#    'vol': '192269.76363016',
#    'volValue': '27485.03901849557',
#    'last': '0.139',
#    'averagePrice': '0.14530608',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'POLK-USDT',
#    'symbolName': 'POLK-USDT',
#    'buy': '0.081',
#    'sell': '0.0822',
#    'changeRate': '0.0188',
#    'changePrice': '0.0015',
#    'high': '0.0927',
#    'low': '0.0795',
#    'vol': '903202.14845438',
#    'volValue': '75111.438998458801',
#    'last': '0.0812',
#    'averagePrice': '0.08353059',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'OPCT-BTC',
#    'symbolName': 'OPCT-BTC',
#    'buy': '0.0000021881',
#    'sell': '0.0000022713',
#    'changeRate': '0.1282',
#    'changePrice': '0.0000002569',
#    'high': '0.0000022634',
#    'low': '0.000001992',
#    'vol': '23894.33181035',
#    'volValue': '0.053052798161941718',
#    'last': '0.0000022604',
#    'averagePrice': '0.00000219',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'WRX-USDT',
#    'symbolName': 'WRX-USDT',
#    'buy': '0.2596',
#    'sell': '0.2615',
#    'changeRate': '0.0234',
#    'changePrice': '0.006',
#    'high': '0.266',
#    'low': '0.2543',
#    'vol': '70528.262305',
#    'volValue': '18264.288066056783',
#    'last': '0.2615',
#    'averagePrice': '0.25538206',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'CTSI-USDT',
#    'symbolName': 'CTSI-USDT',
#    'buy': '0.1853',
#    'sell': '0.1857',
#    'changeRate': '0.0054',
#    'changePrice': '0.001',
#    'high': '0.1934',
#    'low': '0.1808',
#    'vol': '701177.65969524',
#    'volValue': '130754.589760870886',
#    'last': '0.1853',
#    'averagePrice': '0.19346318',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '1',
#    'makerCoefficient': '1'},
#   {'symbol': 'HAI-BTC',
#    'symbolName': 'HAI-BTC',
#    'buy': '0.0000007669',
#    'sell': '0.0000007951',
#    'changeRate': '-0.0784',
#    'changePrice': '-0.000000066',
#    'high': '0.0000008567',
#    'low': '0.0000007177',
#    'vol': '1537052.6589173',
#    'volValue': '1.216045342232176227',
#    'last': '0.0000007752',
#    'averagePrice': '0.00000079',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   {'symbol': 'MSWAP-USDT',
#    'symbolName': 'MSWAP-USDT',
#    'buy': '0.00058',
#    'sell': '0.0006',
#    'changeRate': '0.1372',
#    'changePrice': '0.00007',
#    'high': '0.00083',
#    'low': '0.0005',
#    'vol': '356530679.51957089',
#    'volValue': '240274.5150289820823',
#    'last': '0.00058',
#    'averagePrice': '0.00061324',
#    'takerFeeRate': '0.001',
#    'makerFeeRate': '0.001',
#    'takerCoefficient': '2',
#    'makerCoefficient': '2'},
#   ...]}

# %%
kucoinAPI.getTicker('ETH-USDT')
# Out:
# {'time': 1653200229247,
#  'sequence': '1628155674527',
#  'price': '1974.43',
#  'size': '0.1018097',
#  'bestBid': '1974.43',
#  'bestBidSize': '0.9090403',
#  'bestAsk': '1974.44',
#  'bestAskSize': '10.55110554'}

# %%
kucoinAPI.getFullOrderBook('ETH-USDT')
# Out:
# {'code': '400001',
#  'msg': 'Please check the header of your request for KC-API-KEY, KC-API-SIGN, KC-API-TIMESTAMP, KC-API-PASSPHRASE'}
